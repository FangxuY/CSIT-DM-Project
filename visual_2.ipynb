# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('data21_2.csv',low_memory=False)
lbs=['MODERNA','PFIZER\BIONTECH','JANSSEN']
#lbs=data['manu'].value_counts().index
plt.pie(data['manu'].value_counts(),labels=lbs,autopct="%1.1f%%")
plt.title("Percentage of different types of COVID-19 vaccination")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
